# %%
import pandas as pd

# %%
laptop_data = pd.read_csv('windows_laptop.csv')
gpu_data = pd.read_csv('gpu.csv')
cpu_data = pd.read_csv('cpu.csv')

# %%
laptop_data
# Out:
#                         Laptop_name  Year                     CPU  \
# 0                        MSI GT780R  2011    Intel Core i7-2630QM
# 1                   LG A520-T.AE31G  2011    Intel Core i7-2820QM
# 2                   LG P530-K.AN51G  2011     Intel Core i5-2520M
# 3                   LG P420-N.AE21G  2011     Intel Core i5-2410M
# 4    Lenovo ThinkPad T420s 4174-PEG  2011     Intel Core i7-2640M
# ..                              ...   ...                     ...
# 993                        Asus V1S  2007  Intel Core 2 Duo T7300
# 994                     Asus Pro31S  2007  Intel Core 2 Duo T7250
# 995                        Asus V2S  2007  Intel Core 2 Duo T7300
# 996                 Asus U1F-1P003E  2007          Intel Core Duo
# 997                        Asus V1S  2007  Intel Core 2 Duo T7300
#
#                                             GPU  \
# 0                       NVIDIA GeForce GTX 560M
# 1                        NVIDIA GeForce GT 540M
# ...

# %%
gpu_data
# Out:
#                            GPU             GPU memory GPU clock  \
# 0               EGA Wonder 800   256 KB, DRAM, 32 bit    10 MHz
# 1       Graphics Solution Plus    64 KB, DRAM, 32 bit    10 MHz
# 2     VGA Improved Performance   256 KB, DRAM, 32 bit    10 MHz
# 3         Color Emulation Card    32 KB, DRAM, 32 bit    10 MHz
# 4            Graphics Solution    64 KB, DRAM, 32 bit    10 MHz
# ...                        ...                    ...       ...
# 2952           RTX A500 Mobile    4 GB, GDDR6, 64 bit   832 MHz
# 2953                 RTX A5500  24 GB, GDDR6, 384 bit  1170 MHz
# 2954          RTX A5500 Mobile  16 GB, GDDR6, 256 bit   900 MHz
# 2955               T550 Mobile    4 GB, GDDR6, 64 bit  1065 MHz
# 2956                 Tesla T10  24 GB, GDDR6, 384 bit  1305 MHz
#
#      GPU memory clock
# 0               8 MHz
# 1               5 MHz
# 2              10 MHz
# 3               5 MHz
# 4               5 MHz
# ...               ...
# 2952         1500 MHz
# ...

# %%
cpu_data
# Out:
#                    CPU      Cores             Clock Process L3 Cache    TDP
# 0          Athlon 1000         1           1000 MHz  180 nm      NaN   54 W
# 1          Athlon 1000         1           1000 MHz  180 nm      NaN   54 W
# 2          Athlon 1100         1           1100 MHz  180 nm      NaN   60 W
# 3          Athlon 1133         1           1133 MHz  180 nm      NaN   63 W
# 4          Athlon 1200         1           1200 MHz  180 nm      NaN   66 W
# ...                ...        ...               ...     ...      ...    ...
# 2618   Xeon E5-2698 V3   16  / 32    2.3 to 3.6 GHz   22 nm     40MB  135 W
# 2619  Xeon E5-2698A V3   16  / 32    2.8 to 3.2 GHz   22 nm     40MB  165 W
# 2620   Xeon E5-2699 V3   18  / 36    2.3 to 3.6 GHz   22 nm     45MB  145 W
# 2621    Xeon Phi 7120A  61  / 244  1238 to 1333 MHz   22 nm      NaN  300 W
# 2622    Xeon Phi 7120D  61  / 244  1238 to 1333 MHz   22 nm      NaN  270 W
#
# [2623 rows x 6 columns]

# %%
for gpu in laptop_data['GPU']:
    if 'HD' in gpu:
        print(gpu)
# Out:
# Intel HD Graphics 3000
# Intel HD Graphics 3000
# Intel HD Graphics 3000
# AMD Radeon HD 6250
# Intel Graphics Media Accelerator (GMA) HD Graphics
# Intel Graphics Media Accelerator (GMA) HD Graphics
# Intel Graphics Media Accelerator (GMA) HD Graphics
# ATI Mobility Radeon HD 5650
# ATI Mobility Radeon HD 5470
# ATI Mobility Radeon HD 5650
# ATI Radeon HD 4250
# ATI Mobility Radeon HD 5650
# ATI Mobility Radeon HD 540v
# Intel Graphics Media Accelerator (GMA) 4500MHD
# ATI Radeon HD 4250
# ATI Radeon HD 4250
# ATI Mobility Radeon HD 540v
# Intel Graphics Media Accelerator (GMA) 4500MHD
# ATI Mobility Radeon HD 5650
# ATI Radeon HD 4250
# ATI Mobility Radeon HD 5650
# Intel Graphics Media Accelerator (GMA) HD Graphics
# ATI Mobility Radeon HD 4550
# ATI Mobility Radeon HD 4550
# ATI Mobility Radeon HD 4550
# ATI Radeon HD 4250
# ATI Mobility Radeon HD 5430
# ATI Radeon HD 4250
# ATI Mobility Radeon HD 5650
# ATI Mobility Radeon HD 4550
# ...

# %%
gpu_data.dropna()
gpu_data.isnull().sum()
# Out:
# GPU                 17
# GPU memory          17
# GPU clock           17
# GPU memory clock    17
# dtype: int64

# %%
laptop_data.isnull().sum()
# Out:
# Laptop_name      0
# Year             0
# CPU              6
# GPU              0
# Memory           6
# Storage        136
# Display          0
# Weight(kg)       1
# Price          116
# dtype: int64

# %%
laptop_data['Display'][1]
# Out:
# '15.60 inch 16:9, 1920 x 1080 pixel, LP156WF2-TLA1, FPR, 3D TriDef with polarized eyeglasses, glossy:\xa0yes'
