# %%
#import thư viện cần thiết
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/dsproject/clean_data/clean_data_v2.csv")

# %%
CPU = []
for cpu in data['CPU']:
  cpu = cpu.replace('-', ' - ')
  if len(cpu.split()) >= 2:
    name_cpu = cpu.split()[0:2]
    CPU.append(' '.join(name_cpu))
  else:
    CPU.append(cpu)

data['CPU'] = CPU

# %%
data
# Out:
#       Unnamed: 0                                   Laptop_name  Year       OS  \
# 0              0                   MSI CreatorPro Z16P B12UKST  2022  Windows
# 1              1       Xiaomi RedmiBook Pro 15, i5-11320H iGPU  2022  Windows
# 2              2                 LG Ultra-PC 16 16U70Q-G.AR36G  2022  Windows
# 3              3         Lenovo Legion Slim 7-16IAH 82TF004YGE  2022  Windows
# 4              4                      Lenovo Legion S7 16ARHA7  2022  Windows
# ...          ...                                           ...   ...      ...
# 1902        1902        Apple MacBook Pro 14 2021 M1 Pro Entry  2021    MacOS
# 1903        1903  Apple MacBook Pro 14 2021 M1 Max 24-Core GPU  2021    MacOS
# 1904        1904                    Acer Swift 1 SF114-34-P6U1  2021    Linux
# 1905        1905                    Acer Nitro 5 AN515-45-R36S  2021    Linux
# 1906        1906                    Acer Nitro 5 AN515-57-56HH  2021    Linux
#
#                  CPU  CPU_Cores  CPU_Threads  CPU_Default_Clock  \
# 0            core i7         14           20                2.3
# 1            core i5          4            8                2.5
# 2            ryzen 3          4            8                2.6
# 3            core i7         14           20                2.3
# 4            ryzen 9          8           16                3.3
# ...              ...        ...          ...                ...
# 1902        apple m1          8            8                3.2
# 1903        apple m1         10           10                3.2
# 1904  pentium silver          4            4                1.1
# 1905         ryzen 7          8           16                3.2
# 1906         core i5          6           12                2.2
#
#       CPU_Boosted_Clock  CPU_Transistor_Size(nm)  ...  RAM(GB)  RAM_bus  \
# 0                   4.7                       10  ...       32        0
# 1                   4.5                       10  ...       16        0
# 2                   3.8                        7  ...        8        0
# 3                   4.7                       10  ...       16        0
# 4                   4.9                        6  ...       16        0
# ...                 ...                      ...  ...      ...      ...
# 1902                NaN                        5  ...       16        0
# 1903                NaN                        5  ...       32        0
# 1904                3.3                       10  ...        4        0
# 1905                4.4                        7  ...       16        0
# 1906                4.5                       10  ...        8        0
#
#      RAM_DDR  Storage(GB) Storage_Type  Display_Inch  Display_Height(pixel)  \
# 0          5         1024          SSD          16.0                   2560
# 1          4          512          SSD          15.6                   3200
# 2          4          512          SSD          16.0                   1280
# 3          5         1024          SSD          16.0                   2560
# 4          5         1024          SSD          16.0                   2560
# ...      ...          ...          ...           ...                    ...
# 1902       4          512          SSD          14.2                   3024
# 1903       4          512          SSD          14.2                   3024
# 1904       4          128          SSD          14.0                   1920
# 1905       4         1024          SSD          15.6                   1920
# 1906       4          512          SSD          15.6                   1920
#
#       Display_Width(pixel)  Weight(kg)  Price(USD)
# 0                     1600       2.372      3679.0
# 1                     2000       1.745         NaN
# 2                     1200       1.599         NaN
# 3                     1600       2.206      2313.0
# 4                     1600       2.181      1950.0
# ...                    ...         ...         ...
# 1902                  1964       1.600      2660.0
# 1903                  1964       1.600      3795.0
# 1904                  1080       1.300       413.0
# 1905                  1080       2.300         NaN
# 1906                  1080       2.300      1088.0
#
# [1907 rows x 28 columns]

# %%
# bỏ cột Stt 
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
# understanding the data

# %%
data.columns
# Out:
# Index(['Laptop_name', 'Year', 'OS', 'CPU', 'CPU_Cores', 'CPU_Threads',
#        'CPU_Default_Clock', 'CPU_Boosted_Clock', 'CPU_Transistor_Size(nm)',
#        'CPU_L3(MB)', 'CPU_TDP(W)', 'GPU', 'GPU_Memory(GB)', 'GPU_Memory_Type',
#        'GPU_Bus_Width(bit)', 'GPU clock(MHz)', 'GPU memory clock(MHz)',
#        'RAM(GB)', 'RAM_bus', 'RAM_DDR', 'Storage(GB)', 'Storage_Type',
#        'Display_Inch', 'Display_Height(pixel)', 'Display_Width(pixel)',
#        'Weight(kg)', 'Price(USD)'],
#       dtype='object')

# %%
data.head(5)
# Out:
#                                Laptop_name  Year       OS      CPU  CPU_Cores  \
# 0              MSI CreatorPro Z16P B12UKST  2022  Windows  core i7         14
# 1  Xiaomi RedmiBook Pro 15, i5-11320H iGPU  2022  Windows  core i5          4
# 2            LG Ultra-PC 16 16U70Q-G.AR36G  2022  Windows  ryzen 3          4
# 3    Lenovo Legion Slim 7-16IAH 82TF004YGE  2022  Windows  core i7         14
# 4                 Lenovo Legion S7 16ARHA7  2022  Windows  ryzen 9          8
#
#    CPU_Threads  CPU_Default_Clock  CPU_Boosted_Clock  CPU_Transistor_Size(nm)  \
# 0           20                2.3                4.7                       10
# 1            8                2.5                4.5                       10
# 2            8                2.6                3.8                        7
# 3           20                2.3                4.7                       10
# 4           16                3.3                4.9                        6
#
#    CPU_L3(MB)  ...  RAM(GB) RAM_bus  RAM_DDR Storage(GB)  Storage_Type  \
# 0          24  ...       32       0        5        1024           SSD
# 1           8  ...       16       0        4         512           SSD
# 2           4  ...        8       0        4         512           SSD
# 3          24  ...       16       0        5        1024           SSD
# 4          16  ...       16       0        5        1024           SSD
#
#    Display_Inch  Display_Height(pixel)  Display_Width(pixel)  Weight(kg)  \
# 0          16.0                   2560                  1600       2.372
# 1          15.6                   3200                  2000       1.745
# 2          16.0                   1280                  1200       1.599
# 3          16.0                   2560                  1600       2.206
# 4          16.0                   2560                  1600       2.181
#
#    Price(USD)
# 0      3679.0
# 1         NaN
# 2         NaN
# 3      2313.0
# 4      1950.0
#
# [5 rows x 27 columns]

# %%
data.tail(5)
# Out:
#                                        Laptop_name  Year     OS  \
# 1902        Apple MacBook Pro 14 2021 M1 Pro Entry  2021  MacOS
# 1903  Apple MacBook Pro 14 2021 M1 Max 24-Core GPU  2021  MacOS
# 1904                    Acer Swift 1 SF114-34-P6U1  2021  Linux
# 1905                    Acer Nitro 5 AN515-45-R36S  2021  Linux
# 1906                    Acer Nitro 5 AN515-57-56HH  2021  Linux
#
#                  CPU  CPU_Cores  CPU_Threads  CPU_Default_Clock  \
# 1902        apple m1          8            8                3.2
# 1903        apple m1         10           10                3.2
# 1904  pentium silver          4            4                1.1
# 1905         ryzen 7          8           16                3.2
# 1906         core i5          6           12                2.2
#
#       CPU_Boosted_Clock  CPU_Transistor_Size(nm)  CPU_L3(MB)  ...  RAM(GB)  \
# 1902                NaN                        5          24  ...       16
# 1903                NaN                        5          48  ...       32
# 1904                3.3                       10           4  ...        4
# 1905                4.4                        7          16  ...       16
# 1906                4.5                       10          12  ...        8
#
#      RAM_bus  RAM_DDR Storage(GB)  Storage_Type  Display_Inch  \
# 1902       0        4         512           SSD          14.2
# 1903       0        4         512           SSD          14.2
# 1904       0        4         128           SSD          14.0
# 1905       0        4        1024           SSD          15.6
# 1906       0        4         512           SSD          15.6
#
#       Display_Height(pixel)  Display_Width(pixel)  Weight(kg)  Price(USD)
# 1902                   3024                  1964         1.6      2660.0
# 1903                   3024                  1964         1.6      3795.0
# 1904                   1920                  1080         1.3       413.0
# 1905                   1920                  1080         2.3         NaN
# 1906                   1920                  1080         2.3      1088.0
#
# [5 rows x 27 columns]

# %%
data.shape
# Out:
# (1907, 27)

# %%
data.isnull().sum() # check data rỗng
# Out:
# Laptop_name                  0
# Year                         0
# OS                           0
# CPU                          0
# CPU_Cores                    0
# CPU_Threads                  0
# CPU_Default_Clock            0
# CPU_Boosted_Clock           65
# CPU_Transistor_Size(nm)      0
# CPU_L3(MB)                   0
# CPU_TDP(W)                   0
# GPU                          0
# GPU_Memory(GB)               0
# GPU_Memory_Type            991
# GPU_Bus_Width(bit)           0
# GPU clock(MHz)               0
# GPU memory clock(MHz)        0
# RAM(GB)                      0
# RAM_bus                      0
# RAM_DDR                      0
# Storage(GB)                  0
# Storage_Type                 0
# Display_Inch                 0
# Display_Height(pixel)        0
# Display_Width(pixel)         0
# Weight(kg)                   0
# Price(USD)                 952
# dtype: int64

# %%
# fillna cho 65 chỗ trống
data['CPU_Boosted_Clock'].fillna(value = data['CPU_Boosted_Clock'].mean())
# Out:
# 0       4.700000
# 1       4.500000
# 2       3.800000
# 3       4.700000
# 4       4.900000
#           ...
# 1902    4.424131
# 1903    4.424131
# 1904    3.300000
# 1905    4.400000
# 1906    4.500000
# Name: CPU_Boosted_Clock, Length: 1907, dtype: float64

# %%
# cột GPU_Memory_Type thiếu nhiều quá nên drop
data = data.drop(columns = 'GPU_Memory_Type')

# %%
data.columns
# Out:
# Index(['Laptop_name', 'Year', 'OS', 'CPU', 'CPU_Cores', 'CPU_Threads',
#        'CPU_Default_Clock', 'CPU_Boosted_Clock', 'CPU_Transistor_Size(nm)',
#        'CPU_L3(MB)', 'CPU_TDP(W)', 'GPU', 'GPU_Memory(GB)',
#        'GPU_Bus_Width(bit)', 'GPU clock(MHz)', 'GPU memory clock(MHz)',
#        'RAM(GB)', 'RAM_bus', 'RAM_DDR', 'Storage(GB)', 'Storage_Type',
#        'Display_Inch', 'Display_Height(pixel)', 'Display_Width(pixel)',
#        'Weight(kg)', 'Price(USD)'],
#       dtype='object')

# %%
# fillna cho 65 giá trị trống của CPU_Boosted_Clock
data['CPU_Boosted_Clock'] = data['CPU_Boosted_Clock'].fillna(value=data['CPU_Boosted_Clock'].mean())

# %%
data.isnull().sum() # check data rỗng
# Out:
# Laptop_name                  0
# Year                         0
# OS                           0
# CPU                          0
# CPU_Cores                    0
# CPU_Threads                  0
# CPU_Default_Clock            0
# CPU_Boosted_Clock            0
# CPU_Transistor_Size(nm)      0
# CPU_L3(MB)                   0
# CPU_TDP(W)                   0
# GPU                          0
# GPU_Memory(GB)               0
# GPU_Bus_Width(bit)           0
# GPU clock(MHz)               0
# GPU memory clock(MHz)        0
# RAM(GB)                      0
# RAM_bus                      0
# RAM_DDR                      0
# Storage(GB)                  0
# Storage_Type                 0
# Display_Inch                 0
# Display_Height(pixel)        0
# Display_Width(pixel)         0
# Weight(kg)                   0
# Price(USD)                 952
# dtype: int64

# %%
# Tạm thời xóa 952 hàng không có Price
# Sau này lấy 952 hàng này làm Validation set

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (955, 26)

# %%
data.describe()
# Out:
#               Year   CPU_Cores  CPU_Threads  CPU_Default_Clock  \
# count   955.000000  955.000000   955.000000         955.000000
# mean   2021.464921    7.042932    12.280628           2.420492
# std       0.499029    3.473958     4.840949           0.675828
# min    2021.000000    2.000000     2.000000           1.000000
# 25%    2021.000000    4.000000     8.000000           2.000000
# 50%    2021.000000    6.000000    12.000000           2.400000
# 75%    2022.000000    8.000000    16.000000           2.800000
# max    2022.000000   16.000000    24.000000           4.800000
#
#        CPU_Boosted_Clock  CPU_Transistor_Size(nm)  CPU_L3(MB)  CPU_TDP(W)  \
# count         955.000000               955.000000  955.000000  955.000000
# mean            4.461616                 9.674346   13.839791   31.173822
# std             0.433670                 2.158723    6.503868   11.796899
# min             2.600000                 5.000000    4.000000    6.000000
# 25%             4.200000                 7.000000    8.000000   26.500000
# 50%             4.500000                10.000000   12.000000   28.000000
# 75%             4.700000                10.000000   16.000000   45.000000
# max             5.300000                14.000000   48.000000   55.000000
#
#        GPU_Memory(GB)  GPU_Bus_Width(bit)  ...  GPU memory clock(MHz)  \
# count      955.000000          955.000000  ...             955.000000
# mean         2.952880           85.679581  ...             802.964398
# std          3.727747           99.290449  ...             842.486700
# min          0.000000            0.000000  ...               0.000000
# 25%          0.000000            0.000000  ...               0.000000
# 50%          0.000000            0.000000  ...               0.000000
# 75%          6.000000          192.000000  ...            1750.000000
# max         16.000000          256.000000  ...            2250.000000
#
#           RAM(GB)      RAM_bus     RAM_DDR  Storage(GB)  Display_Inch  \
# count  955.000000   955.000000  955.000000   955.000000    955.000000
# mean    17.089005   146.759162    4.104712   698.839791     15.061675
# std      9.735465   678.817669    0.385166   388.694113      1.266914
# min      4.000000     0.000000    1.000000   128.000000     11.600000
# 25%     16.000000     0.000000    4.000000   512.000000     14.000000
# 50%     16.000000     0.000000    4.000000   512.000000     15.600000
# 75%     16.000000     0.000000    4.000000  1024.000000     15.600000
# max     64.000000  5200.000000    5.000000  2048.000000     17.300000
#
#        Display_Height(pixel)  Display_Width(pixel)  Weight(kg)   Price(USD)
# count             955.000000            955.000000  955.000000   955.000000
# mean             2229.778010           1297.949738    1.832308  1757.872251
# std               588.817798            372.777975    0.529161  1069.649432
# min              1366.000000            768.000000    0.719000   263.000000
# 25%              1920.000000           1080.000000    1.400000  1000.000000
# 50%              1920.000000           1080.000000    1.750000  1472.000000
# 75%              2560.000000           1440.000000    2.250000  2247.000000
# max              3840.000000           2400.000000    4.500000  6860.000000
#
# [8 rows x 21 columns]

# %%
data.nunique()
# Out:
# Laptop_name                955
# Year                         2
# OS                           3
# CPU                         21
# CPU_Cores                    8
# CPU_Threads                  9
# CPU_Default_Clock           25
# CPU_Boosted_Clock           24
# CPU_Transistor_Size(nm)      6
# CPU_L3(MB)                  11
# CPU_TDP(W)                  12
# GPU                         81
# GPU_Memory(GB)               8
# GPU_Bus_Width(bit)           6
# GPU clock(MHz)              48
# GPU memory clock(MHz)       14
# RAM(GB)                      6
# RAM_bus                     16
# RAM_DDR                      4
# Storage(GB)                  5
# Storage_Type                 1
# Display_Inch                19
# Display_Height(pixel)       17
# Display_Width(pixel)        21
# Weight(kg)                 352
# Price(USD)                 312
# dtype: int64

# %%
# Relationship analysis
# Feature hơi nhiều nên chỉ test với một số feature có tính decision cao

# %%
data_test = data[['CPU', 'CPU_Cores','GPU','RAM(GB)','Storage(GB)','Price(USD)']]

# %%
data_test
# Out:
#                  CPU  CPU_Cores                        GPU  RAM(GB)  \
# 0            core i7         14           rtx a3000 mobile       32
# 3            core i7         14    geforce rtx 3060 mobile       16
# 4            ryzen 9          8            radeon rx 6800s       16
# 5            core i7         12  iris xe graphics g7 96eus       16
# 6            ryzen 5          6                radeon 660m       16
# ...              ...        ...                        ...      ...
# 1901        apple m1         10   apple m1 pro 16-core gpu       16
# 1902        apple m1          8   apple m1 pro 14-core gpu       16
# 1903        apple m1         10   apple m1 max 24-core gpu       32
# 1904  pentium silver          4               uhd graphics        4
# 1906         core i5          6    geforce rtx 3050 mobile        8
#
#       Storage(GB)  Price(USD)
# 0            1024      3679.0
# 3            1024      2313.0
# 4            1024      1950.0
# 5            1024      2311.0
# 6             512      1472.0
# ...           ...         ...
# 1901         1024      3523.0
# 1902          512      2660.0
# 1903          512      3795.0
# 1904          128       413.0
# 1906          512      1088.0
#
# [955 rows x 6 columns]

# %%
corelation = data_test.corr()

# %%
plt.figure(figsize=(14,12))
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns, annot = True)

# %%
sns.pairplot(data_test)

# %%
#sns.relplot(x='RAM(GB', y='Storage(GB)', hue='CPU_Cores', data = data_test)

# %%
sns.distplot(data_test['Price(USD)'])

# %%
sns.distplot(data_test['RAM(GB)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x='Price(USD)', kind = 'box', data = data_test)

# %%
data_test['CPU'].unique()
# Out:
# array(['core i7', 'ryzen 9', 'ryzen 5', 'core i9', 'pentium gold',
#        'core i5', 'ryzen 7', 'pentium silver', 'celeron n4120', 'ryzen 3',
#        'core i3', 'celeron n5100', 'celeron n4500', 'xeon w',
#        'celeron 6305', 'apple m2', 'athlon gold', 'celeron n4020',
#        '3020e', 'celeron n4000', 'apple m1'], dtype=object)

# %%
plt.figure(figsize = (30,7))
sns.boxplot(x = 'CPU',y = 'Price(USD)', data = data_test)

# %%
plt.figure(figsize=(30,7))
sns.barplot(
        x = data['CPU'],
        y = data_test['Price(USD)'],
        data = data_test
    )
